# %% [markdown]
# # Titanic_Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Data Overview

# %%
# identify the total number of passengers
df = pd.read_csv('C:\\Users\\Vishaly\\OneDrive\\Documents\\coding\\titanic\\train.csv')
df['PassengerId'].count()
# Out:
# 891

# %%
# identify the number of survivors
df = pd.read_csv('C:\\Users\\Vishaly\\OneDrive\\Documents\\coding\\titanic\\train.csv')
df['Survived'].sum()
# Out:
# 342

# %%
# identify the numbe of passengers survived under 18
df = pd.read_csv('C:\\Users\\Vishaly\\OneDrive\\Documents\\coding\\titanic\\train.csv')
df[df['Age'] < 18]['Survived'].sum()
# Out:
# 61

# %%
# identify the number of male and female passengers
df = pd.read_csv('C:\\Users\\Vishaly\\OneDrive\\Documents\\coding\\titanic\\train.csv')
df.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked
# Sex
# female     97       312
# male      107       577

# %%
# import file from excel named train
df = pd.read_csv('C:\\Users\\Vishaly\\OneDrive\\Documents\\coding\\titanic\\train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# unique values for the "Sex" column
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# encode the "Sex" column with 0 and 1
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

# %%
# unique values for the "Embarked" column
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
# encode the "Embarked" column with 0, 1, 2
df['Embarked'] = df['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})

# %%
# describe the data
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   891.000000  891.000000  891.000000  891.000000  714.000000
# mean    446.000000    0.383838    2.308642    0.352413   29.699118
# std     257.353842    0.486592    0.836071    0.477990   14.526497
# min       1.000000    0.000000    1.000000    0.000000    0.420000
# 25%     223.500000    0.000000    2.000000    0.000000   20.125000
# 50%     446.000000    0.000000    3.000000    0.000000   28.000000
# 75%     668.500000    1.000000    3.000000    1.000000   38.000000
# max     891.000000    1.000000    3.000000    1.000000   80.000000
#
#             SibSp       Parch        Fare    Embarked
# count  891.000000  891.000000  891.000000  889.000000
# mean     0.523008    0.381594   32.204208    0.362205
# std      1.102743    0.806057   49.693429    0.636157
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    7.910400    0.000000
# 50%      0.000000    0.000000   14.454200    0.000000
# 75%      1.000000    0.000000   31.000000    1.000000
# max      8.000000    6.000000  512.329200    2.000000

# %%
# identify number of rows and columns
df.shape
# Out:
# (891, 12)

# %%
# identify missing values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# identify datatype
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked       float64
# dtype: object

# %%
# identify unique values
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# #### Graphs representing data

# %%
# draw a box plot of all numerical variables with outliers with labels
figsize = (12,12)
df.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False, fontsize=8, figsize=(12,12))
plt.show()

# %%
# draw a histogram of all numerical variables with labels
figsize = (11,11)
df.plot(kind='hist', subplots=True, layout=(3,3), sharex=False, sharey=False, fontsize=1, figsize=figsize)
plt.show()

# %%
# draw a scatter matrix of all numerical variables
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize=(11,11))
plt.show()

# %% [markdown]
# ## Data Normalization (Scaling)

# %%
# remove missing value from age
df.dropna(subset=['Age'], inplace=True)

# %%
# identify all missing values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         2
# dtype: int64

# %%
# remove all the missing values from embarked
df.dropna(subset=['Embarked'], inplace=True)

# %%
# identify unquie values for embarked
df['Embarked'].unique()
# Out:
# array([0., 1., 2.])

# %%
# identify all missing values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         0
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked       float64
# dtype: object

# %%
# identify all unique values
df.nunique()
# Out:
# PassengerId    712
# Survived         2
# Pclass           3
# Name           712
# Sex              2
# Age             88
# SibSp            6
# Parch            7
# Ticket         541
# Fare           219
# Cabin          133
# Embarked         3
# dtype: int64

# %%
# identify the unique values for age
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  , 54.  ,  2.  , 27.  , 14.  ,  4.  ,
#        58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,  8.  ,
#        19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  , 49.  ,
#        29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  , 16.  ,
#        25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  , 71.  ,
#        37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 , 51.  ,
#        55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  , 45.5 ,
#        20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  , 60.  ,
#        10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  , 70.  ,
#        24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
# identify all unique values for SipSp
df['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5], dtype=int64)

# %%
# identify all unique values for Parch
df['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6], dtype=int64)

# %%
# identify all unique values for Fare
df['Fare'].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,  51.8625,
#         21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,  31.275 ,
#          7.8542,  16.    ,  29.125 ,  18.    ,  26.    ,  13.    ,
#          8.0292,  35.5   ,  31.3875, 263.    ,  27.7208,  10.5   ,
#         82.1708,  52.    ,  11.2417,   9.475 ,  21.    ,  41.5792,
#          7.8792,  17.8   ,  39.6875,   7.8   ,  76.7292,  61.9792,
#          7.2292,  27.75  ,  46.9   ,  83.475 ,  27.9   ,   8.1583,
#          8.6625,  73.5   ,  14.4542,  56.4958,   7.65  ,  29.    ,
#         12.475 ,   9.    ,   9.5   ,  47.1   ,  15.85  ,  34.375 ,
#         61.175 ,  20.575 ,  34.6542,  63.3583,  23.    ,   7.8958,
#         77.2875,   8.6542,   9.825 ,  14.4583,   7.75  , 247.5208,
#          7.1417,   6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,
#          9.2167,  79.2   ,   6.75  ,  11.5   ,  36.75  ,   7.7958,
#         12.525 ,  66.6   ,  61.3792,   7.7333,  16.1   ,  15.75  ,
#          7.775 ,  20.525 ,  33.5   ,  30.6958,  28.7125,   0.    ,
#         39.    ,  22.025 ,  15.5   , 146.5208,   8.4042,   6.4958,
#          7.225 ,  10.4625,  18.7875,  31.    , 113.275 ,  27.    ,
#         76.2917,  90.    ,   9.35  ,  13.5   ,  26.25  ,  12.275 ,
#          7.125 ,  52.5542,  20.2125,  15.2458,  86.5   , 512.3292,
#         79.65  , 153.4625, 135.6333,  19.5   ,  29.7   ,  77.9583,
#         20.25  ,  78.85  ,  91.0792,  12.875 ,   8.85  , 151.55  ,
#        108.9   ,  24.    ,  56.9292,  83.1583, 262.375 ,  14.    ,
#        164.8667, 134.5   ,  12.35  ,   6.2375,  57.9792,  28.5   ,
#         15.9   ,   9.225 ,  55.    ,  75.25  ,  69.3   ,  55.4417,
#        211.5   ,   4.0125, 227.525 ,  15.7417,  12.    , 120.    ,
#         12.65  ,  18.75  ,  32.5   ,  24.15  ,   7.875 ,  14.4   ,
#         55.9   ,  81.8583,  19.2583,  30.5   ,  89.1042,  38.5   ,
#         13.7917,   9.8375,   7.0458,   7.5208,  12.2875,   9.5875,
#         49.5042,  78.2667,  22.525 ,  26.2875,  59.4   ,   7.4958,
#         34.0208,  93.5   , 106.425 ,  49.5   ,  71.    , 110.8833,
#         39.6   ,  17.4   ,  51.4792,  26.3875,  30.    ,  40.125 ,
#         15.    ,  15.55  ,  65.    ,  32.3208,   7.0542,   7.55  ,
#          8.4333, 133.65  ,  25.5875,   9.8417,  10.1708, 211.3375,
#         57.    ,  13.4167,   7.7417,   9.4833,  33.    ,   8.3625,
#         25.9292,   8.6833,   8.5167,   7.8875,  37.0042,   6.45  ,
#          8.3   ,   6.4375,  39.4   ,  14.1083,  13.8583,  50.4958,
#          5.    ,   9.8458,  10.5167])

# %%
# identify the max age 
df['Age'].max()
# Out:
# 80.0

# %%
# indentify the max fare
df['Fare'].max()
# Out:
# 512.3292

# %%
# draw a scatter plot for all values in fare with age 80 and below
df.plot(kind='scatter', x='Age', y='Fare', alpha=0.5, s=10, figsize=(12, 8), c='Survived', cmap=plt.get_cmap('coolwarm'))

plt.show()

# %%
# remove the outlier above 500 in fare
df = df[df['Fare'] < 500]

# %%
# draw a scatter plot for all values in fare with age 80 and below
df.plot(kind='scatter', x='Age', y='Fare', alpha=0.5, s=10, figsize=(12, 8), c='Survived', cmap=plt.get_cmap('coolwarm'))

plt.show()

# %%
# identify data types
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked       float64
# dtype: object

# %%
# identify all unique values
df.nunique()
# Out:
# PassengerId    709
# Survived         2
# Pclass           3
# Name           709
# Sex              2
# Age             88
# SibSp            6
# Parch            7
# Ticket         540
# Fare           218
# Cabin          132
# Embarked         3
# dtype: int64

# %%
# draw a box plot of all numerical variables with outliers with labels
figsize = (12,12)
df.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False, fontsize=8, figsize=(12,12))
plt.show()

# %%
# remove non-numeric columns
df = df.select_dtypes(include=[np.number])


# show correlation
df.corr()
# show heatmap
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# #### Training

# %%
# normalize the data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
# use logistic regression
from sklearn.linear_model import LogisticRegression

# use train test split
from sklearn.model_selection import train_test_split

# use confusion matrix
from sklearn.metrics import confusion_matrix

# use classification report
from sklearn.metrics import classification_report

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
# let x= all the numerical columns except survived
x = df.drop(['Survived'], axis=1)
# y=Survived
y = df['Survived']

# split the data into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# use logistic regression
lr = LogisticRegression()

# fit the model
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### Testing

# %%
predictions = lr.predict(x_test)

cm = confusion_matrix(y_test, predictions)
print("Confusion Matrix:\n", cm)

cr = classification_report(y_test, predictions)
print("Classification Report:\n", cr)
# Out:
# Confusion Matrix:
#  [[74 17]
#  [18 33]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.80      0.81      0.81        91
#          1.0       0.66      0.65      0.65        51
#
#     accuracy                           0.75       142
#    macro avg       0.73      0.73      0.73       142
# weighted avg       0.75      0.75      0.75       142
